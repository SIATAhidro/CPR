# %%
import os
from cprv1 import cprv1 as cpr
import numpy as np
import pandas as pd
import datetime
codigo = 99
simubasin = True
if simubasin:
    path_nc = '/home/mcano/data/basins/%s.nc'%codigo
else:
    path_nc = None
self = cpr.Nivel(codigo=codigo,user='sample_user',passwd='s@mple_p@ss',path_nc=path_nc)
self.GetGeo_Cell_Basics()
self.GetGeo_Parameters()
self.table = 'estaciones_estaciones'
fields = self.read_sql('describe %s'%self.table)['Field'].values
df = pd.DataFrame(cpr.info.ESTACIONES).T
df.columns = ['label','siata_name']
siata_table = df['siata_name'].dropna()
remote = cpr.SqlDb(**cpr.info.REMOTE)
REDES = cpr.info.REDES
format = str(REDES)[1:-1]
CODIGOS = remote.read_sql("SELECT Codigo FROM estaciones WHERE Red in (%s) and estado = 'A'"%format)['Codigo']
CODIGOS = str(np.array(CODIGOS.values,str))[1:-1].replace('\n','').replace("' '","','")
FIELDS = ','.join(siata_table.values)
consulta = remote.read_sql("SELECT %s FROM estaciones WHERE Codigo in (%s)"%(FIELDS,CODIGOS))
consulta[consulta==-999]=np.NaN
consulta[consulta.isnull()]=np.NaN
upload = pd.DataFrame(index = consulta.index,columns = df.index)
df['local'] = df.index
consulta.columns = df.set_index('siata_name').loc[consulta.columns,'local'].values
upload[consulta.columns]=consulta
offset_old = upload['offset_old']
offset_old[offset_old==0.0] = np.NaN
upload['offset_old'] = offset_old
now = datetime.datetime.now().strftime('%Y-%m-%d')
upload[['timestamp','updated']] = now
upload['usr'] = 'mario'
upload['vel_sup'] = 0
upload['slug'] = map(lambda x:x.replace(' ','').replace('.','').replace('-','').replace('(','').replace(')',''),upload['nombre'].values)
upload['user_id'] = 1
self.table = 'estaciones_estaciones'
upload['slug']=upload['codigo'].astype(str)+'-'+upload['slug']

def insert_data(self,fields,values,*keys,**kwargs):
    '''
    inserts data into SQL table from list of fields and values
    Parameters
    ----------
    fields   = list of fields names from SQL db
    values   = list of values to be inserted
    Example
    -------
    insert_data(['fecha','nivel'],['2017-07-13',0.5])
    '''
    values = str(list(values)).strip('[]')
    fields = str(list(fields)).strip('[]').replace("'","")
    execution = 'INSERT INTO %s (%s) VALUES (%s)'%(self.table,fields,values)
    return execution
upload['flag_modelo_wmf']='0'
upload.loc[upload[upload['codigo']==99].index[0],'flag_modelo_wmf'] = 1
codigos_nivel = remote.read_sql("select Codigo,NombreEstacion,red from estaciones where estado = 'A' and (red='nivel' or red='mocoa-nivel')")['Codigo'].values
serie = pd.Series(upload['codigo'].index,index=upload['codigo'].values).loc[codigos_nivel]
# estaciones con velocidad superficial
upload.loc[serie.loc[[99,92,106,140]].values,'vel_sup']=[157,176,177,185]
upload.loc[serie.loc[codigos_nivel].values,'clase'] = 'Nivel'
query = "SELECT Codigo FROM estaciones where red in ('Pluviografica','mocoa-pluvio','pluviografica') and estado = 'A'"
codigos_pluvio = remote.read_sql(query)['Codigo'].values
serie = pd.Series(upload['codigo'].index,index=upload['codigo'].values).loc[codigos_pluvio]
upload.loc[serie.loc[codigos_pluvio].values,'clase'] = 'Pluvio'
serie = pd.Series(upload['codigo'].index,index=upload['codigo'].values).loc[codigos_nivel]
basins_main_path = '/home/mcano/data/basins/'
upload.loc[serie.values,'nc_path'] = map(lambda x: '%s%s.nc'%(basins_main_path,x),np.array(serie.index,str))
for shape in ['polygon','net','stream']:
    shape_path = "/home/mcano/data/shapes/%s/"%shape
    upload.loc[serie.values,'%s_path'%shape] = map(lambda x: '%s%s/%s'%(shape_path,x,x),np.array(serie.index,str))
for count,codigo in enumerate(codigos_nivel): 
    try:
        print('%.2f %%,%s out of %s'%((count+1)*100.0/len(codigos_nivel),count+1,len(codigos_nivel)))
        if simubasin:
            path_nc = '/home/mcano/data/basins/%s.nc'%codigo
        else:
            path_nc = None
        self = cpr.Nivel(codigo=codigo,user='sample_user',passwd='s@mple_p@ss',path_nc=path_nc)
        self.GetGeo_Cell_Basics()
        self.GetGeo_Parameters()
        df = pd.DataFrame(pd.Series(self.GeoParameters))
        df.loc[cpr.info.GEOPARAMETERS.keys(),'field'] = cpr.info.GEOPARAMETERS.values()
        df = df.set_index('field')[0]
        df = df[df.index.dropna()]
        upload.loc[serie.loc[self.codigo],df.index] = df.values
    except:
        print 'failed:%s'%codigo
self.table = 'estaciones_estaciones'
codigos = [ 128,108,245,109,106,186,124,135,247,140,96,101,246,92,94,245,238,251,1014,
            1013,260,158,182,93,239,90,104,143,183,240,99,91,115,116,134,152,166,179,
            155,236,173,178,196,195,259,268,98,272,273 ]

x_sensor = [ 8.0,4.23,11.66,3.5,17.0,5.75,12.6,3.08,3.0,24.0,4.2,0.8,4.2,1.3,12.11,11.66,
            12.54,4.1,6.88,8.74,21.0,3.87,2.45,31.17,6.4,11.6,2.55,4.66,2.8,1.5,21.0,18.95,
            1.55,8.21,2.5,3.0,2.0,8.0,5.5,14.0,2.0,1.5,29.8,3.92,2.42,4.4,5.0,5.74,3.18 ]
@property
def offsetData(self):
    '''Tabla historico_bancallena_offset'''
    df = self.mysql_query('select * from historico_bancallena_offset;')
    df.columns = self.mysql_query('describe historico_bancallena_offset;')[0].values
    df[df==-9999]=np.NaN
    return df.set_index('codigo')

print 'stations without x_sensor'
for codigo in codigos_nivel:
    self = cpr.Nivel(codigo=codigo,user='sample_user',passwd='s@mple_p@ss')
    upload.loc[serie[codigo],'offset'] = self.offset_remote()
    try:
        self.x_sensor = cpr.info.X_SENSOR[self.codigo]
        upload.loc[serie[codigo],'x_sensor'] = self.x_sensor
    except:
        print self.codigo
    upload.loc[serie[codigo],'sirena'] = '0'
pictures_main_path = '/home/mcano/data/pics/'
# making directories
for codigo in codigos_nivel:
    ruta_folder = pictures_main_path+str(codigo)
    os.system('mkdir %s'%ruta_folder)
    upload.loc[serie[codigo],'pic_path'] = ruta_folder
    
self.table = 'estaciones_estaciones'
index = upload.fillna('NULL').index
for count,ids in enumerate(index):
    print('%.2f %%,%s out of %s'%((count+1)*100.0/len(index),count+1,len(index)))
    serie = upload.fillna('NULL').loc[ids]
    serie.index = map(lambda x:x.encode("utf-8"),serie.index)
    execution = insert_data(self,list(serie.index),list(serie.values)).replace("'NULL'","NULL")
    self.execute_sql(execution)
    
upload.to_csv('/home/mcano/data/migration_%s.csv'%datetime.datetime.now().strftime('%Y%m%d%H%M'))
# Out:
# setting wmf.SimuBasin
# 1.85 %,1 out of 54
# setting wmf.SimuBasin
# 3.70 %,2 out of 54
# setting wmf.SimuBasin
# 5.56 %,3 out of 54
# setting wmf.SimuBasin
# 7.41 %,4 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:93
# 9.26 %,5 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:94
# 11.11 %,6 out of 54
# setting wmf.SimuBasin
# 12.96 %,7 out of 54
# setting wmf.SimuBasin
# 14.81 %,8 out of 54
# setting wmf.SimuBasin
# 16.67 %,9 out of 54
# setting wmf.SimuBasin
# 18.52 %,10 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:106
# 20.37 %,11 out of 54
# setting wmf.SimuBasin
# 22.22 %,12 out of 54
# setting wmf.SimuBasin
# 24.07 %,13 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:91
# 25.93 %,14 out of 54
# setting wmf.SimuBasin
# 27.78 %,15 out of 54
# setting wmf.SimuBasin
# 29.63 %,16 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:124
# 31.48 %,17 out of 54
# setting wmf.SimuBasin
# 33.33 %,18 out of 54
# setting wmf.SimuBasin
# 35.19 %,19 out of 54
# setting wmf.SimuBasin
# 37.04 %,20 out of 54
# setting wmf.SimuBasin
# 38.89 %,21 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:140
# 40.74 %,22 out of 54
# setting wmf.SimuBasin
# 42.59 %,23 out of 54
# setting wmf.SimuBasin
# 44.44 %,24 out of 54
# setting wmf.SimuBasin
# 46.30 %,25 out of 54
# setting wmf.SimuBasin
# 48.15 %,26 out of 54
# setting wmf.SimuBasin
# 50.00 %,27 out of 54
# setting wmf.SimuBasin
# 51.85 %,28 out of 54
# setting wmf.SimuBasin
# 53.70 %,29 out of 54
# setting wmf.SimuBasin
# No se encuentran el DEM y el DIR en la ruta:
# /media/nicolas/Home/nicolas/01_SIATA/raster/dem_amva60.tif
# /media/nicolas/Home/nicolas/01_SIATA/raster/dir_amva60.tif
# failed:179
# 55.56 %,30 out of 54
# setting wmf.SimuBasin
# 57.41 %,31 out of 54
# setting wmf.SimuBasin
# 59.26 %,32 out of 54
# setting wmf.SimuBasin
# 61.11 %,33 out of 54
# setting wmf.SimuBasin
# 62.96 %,34 out of 54
# setting wmf.SimuBasin
# 64.81 %,35 out of 54
# setting wmf.SimuBasin
# 66.67 %,36 out of 54
# setting wmf.SimuBasin
# 68.52 %,37 out of 54
# setting wmf.SimuBasin
# failed:1013
# 70.37 %,38 out of 54
# setting wmf.SimuBasin
# failed:1014
# 72.22 %,39 out of 54
# setting wmf.SimuBasin
# 74.07 %,40 out of 54
# setting wmf.SimuBasin
# 75.93 %,41 out of 54
# setting wmf.SimuBasin
# failed:195
# 77.78 %,42 out of 54
# setting wmf.SimuBasin
# 79.63 %,43 out of 54
# setting wmf.SimuBasin
# 81.48 %,44 out of 54
# setting wmf.SimuBasin
# 83.33 %,45 out of 54
# setting wmf.SimuBasin
# 85.19 %,46 out of 54
# setting wmf.SimuBasin
# 87.04 %,47 out of 54
# setting wmf.SimuBasin
# 88.89 %,48 out of 54
# setting wmf.SimuBasin
# 90.74 %,49 out of 54
# setting wmf.SimuBasin
# 92.59 %,50 out of 54
# setting wmf.SimuBasin
# 94.44 %,51 out of 54
# setting wmf.SimuBasin
# 96.30 %,52 out of 54
# setting wmf.SimuBasin
# 98.15 %,53 out of 54
# setting wmf.SimuBasin
# 100.00 %,54 out of 54
# setting wmf.SimuBasin
# failed:273
# stations without x_sensor
# 145
# 150
# 169
# 161
# 181
# 187
# 192
# 265
# 0.52 %,1 out of 194
# 1.03 %,2 out of 194
# 1.55 %,3 out of 194
# 2.06 %,4 out of 194
# 2.58 %,5 out of 194
# 3.09 %,6 out of 194
# 3.61 %,7 out of 194
# 4.12 %,8 out of 194
# 4.64 %,9 out of 194
# 5.15 %,10 out of 194
# 5.67 %,11 out of 194
# 6.19 %,12 out of 194
# 6.70 %,13 out of 194
# 7.22 %,14 out of 194
# 7.73 %,15 out of 194
# 8.25 %,16 out of 194
# 8.76 %,17 out of 194
# 9.28 %,18 out of 194
# 9.79 %,19 out of 194
# 10.31 %,20 out of 194
# 10.82 %,21 out of 194
# 11.34 %,22 out of 194
# 11.86 %,23 out of 194
# 12.37 %,24 out of 194
# 12.89 %,25 out of 194
# 13.40 %,26 out of 194
# 13.92 %,27 out of 194
# 14.43 %,28 out of 194
# 14.95 %,29 out of 194
# 15.46 %,30 out of 194
# 15.98 %,31 out of 194
# 16.49 %,32 out of 194
# 17.01 %,33 out of 194
# 17.53 %,34 out of 194
# 18.04 %,35 out of 194
# 18.56 %,36 out of 194
# 19.07 %,37 out of 194
# 19.59 %,38 out of 194
# 20.10 %,39 out of 194
# 20.62 %,40 out of 194
# 21.13 %,41 out of 194
# 21.65 %,42 out of 194
# 22.16 %,43 out of 194
# 22.68 %,44 out of 194
# 23.20 %,45 out of 194
# 23.71 %,46 out of 194
# 24.23 %,47 out of 194
# 24.74 %,48 out of 194
# 25.26 %,49 out of 194
# 25.77 %,50 out of 194
# 26.29 %,51 out of 194
# 26.80 %,52 out of 194
# 27.32 %,53 out of 194
# 27.84 %,54 out of 194
# 28.35 %,55 out of 194
# 28.87 %,56 out of 194
# 29.38 %,57 out of 194
# 29.90 %,58 out of 194
# 30.41 %,59 out of 194
# 30.93 %,60 out of 194
# 31.44 %,61 out of 194
# 31.96 %,62 out of 194
# 32.47 %,63 out of 194
# 32.99 %,64 out of 194
# 33.51 %,65 out of 194
# 34.02 %,66 out of 194
# 34.54 %,67 out of 194
# 35.05 %,68 out of 194
# 35.57 %,69 out of 194
# 36.08 %,70 out of 194
# 36.60 %,71 out of 194
# 37.11 %,72 out of 194
# 37.63 %,73 out of 194
# 38.14 %,74 out of 194
# 38.66 %,75 out of 194
# 39.18 %,76 out of 194
# 39.69 %,77 out of 194
# 40.21 %,78 out of 194
# 40.72 %,79 out of 194
# 41.24 %,80 out of 194
# 41.75 %,81 out of 194
# 42.27 %,82 out of 194
# 42.78 %,83 out of 194
# 43.30 %,84 out of 194
# 43.81 %,85 out of 194
# 44.33 %,86 out of 194
# 44.85 %,87 out of 194
# 45.36 %,88 out of 194
# 45.88 %,89 out of 194
# 46.39 %,90 out of 194
# 46.91 %,91 out of 194
# 47.42 %,92 out of 194
# 47.94 %,93 out of 194
# 48.45 %,94 out of 194
# 48.97 %,95 out of 194
# 49.48 %,96 out of 194
# 50.00 %,97 out of 194
# 50.52 %,98 out of 194
# 51.03 %,99 out of 194
# 51.55 %,100 out of 194
# 52.06 %,101 out of 194
# 52.58 %,102 out of 194
# 53.09 %,103 out of 194
# 53.61 %,104 out of 194
# 54.12 %,105 out of 194
# 54.64 %,106 out of 194
# 55.15 %,107 out of 194
# 55.67 %,108 out of 194
# 56.19 %,109 out of 194
# 56.70 %,110 out of 194
# 57.22 %,111 out of 194
# 57.73 %,112 out of 194
# 58.25 %,113 out of 194
# 58.76 %,114 out of 194
# 59.28 %,115 out of 194
# 59.79 %,116 out of 194
# 60.31 %,117 out of 194
# 60.82 %,118 out of 194
# 61.34 %,119 out of 194
# 61.86 %,120 out of 194
# 62.37 %,121 out of 194
# 62.89 %,122 out of 194
# 63.40 %,123 out of 194
# 63.92 %,124 out of 194
# 64.43 %,125 out of 194
# 64.95 %,126 out of 194
# 65.46 %,127 out of 194
# 65.98 %,128 out of 194
# 66.49 %,129 out of 194
# 67.01 %,130 out of 194
# 67.53 %,131 out of 194
# 68.04 %,132 out of 194
# 68.56 %,133 out of 194
# 69.07 %,134 out of 194
# 69.59 %,135 out of 194
# 70.10 %,136 out of 194
# 70.62 %,137 out of 194
# 71.13 %,138 out of 194
# 71.65 %,139 out of 194
# 72.16 %,140 out of 194
# 72.68 %,141 out of 194
# 73.20 %,142 out of 194
# 73.71 %,143 out of 194
# 74.23 %,144 out of 194
# 74.74 %,145 out of 194
# 75.26 %,146 out of 194
# 75.77 %,147 out of 194
# 76.29 %,148 out of 194
# 76.80 %,149 out of 194
# 77.32 %,150 out of 194
# 77.84 %,151 out of 194
# 78.35 %,152 out of 194
# 78.87 %,153 out of 194
# 79.38 %,154 out of 194
# 79.90 %,155 out of 194
# 80.41 %,156 out of 194
# 80.93 %,157 out of 194
# 81.44 %,158 out of 194
# 81.96 %,159 out of 194
# 82.47 %,160 out of 194
# 82.99 %,161 out of 194
# 83.51 %,162 out of 194
# 84.02 %,163 out of 194
# 84.54 %,164 out of 194
# 85.05 %,165 out of 194
# 85.57 %,166 out of 194
# 86.08 %,167 out of 194
# 86.60 %,168 out of 194
# 87.11 %,169 out of 194
# 87.63 %,170 out of 194
# 88.14 %,171 out of 194
# 88.66 %,172 out of 194
# 89.18 %,173 out of 194
# 89.69 %,174 out of 194
# 90.21 %,175 out of 194
# 90.72 %,176 out of 194
# 91.24 %,177 out of 194
# 91.75 %,178 out of 194
# 92.27 %,179 out of 194
# 92.78 %,180 out of 194
# 93.30 %,181 out of 194
# 93.81 %,182 out of 194
# 94.33 %,183 out of 194
# 94.85 %,184 out of 194
# 95.36 %,185 out of 194
# 95.88 %,186 out of 194
# 96.39 %,187 out of 194
# 96.91 %,188 out of 194
# 97.42 %,189 out of 194
# 97.94 %,190 out of 194
# 98.45 %,191 out of 194
# 98.97 %,192 out of 194
# 99.48 %,193 out of 194
# 100.00 %,194 out of 194
